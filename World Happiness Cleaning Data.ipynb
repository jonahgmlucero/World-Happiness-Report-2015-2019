# %% [markdown]
# # World Happiness Data Cleaning and Consistency Checks

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
WH2015 = pd.read_csv(r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness/World Happines CSVs/2015.csv', index_col = False)

# %%
path = r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness'

# %%
WH2015.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
WH2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#Finding Missing Values
WH2015.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#Finding Duplicates
WH2015_dups = WH2015[WH2015.duplicated()]

# %%
WH2015_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
#no duplicated rows

# %%
#Adding a Year Column
WH2015['Year'] = '2015'

# %%
WH2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Year
# ...

# %%
#Drop 'Region', and 'Standard Error'
WH2015 = WH2015.drop('Region', axis=1)
WH2015 = WH2015.drop('Standard Error', axis=1)

# %% [markdown]
# ### Cleaning 2016 Data

# %%
WH2016 = pd.read_csv(r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness/World Happines CSVs/2016.csv', index_col = False)

# %%
WH2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
WH2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %% [markdown]
# #### This is showing that there is one missing country. Since analysis will be based on 'Region', no need to address the missing country.

# %%
#Finding Duplicates
WH2016_dups = WH2016[WH2016.duplicated()]

# %%
WH2016_dups
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
#no duplicates

# %%
#Finding Missing Values
WH2016.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#Adding a Year Column
WH2016['Year'] = '2016'

# %%
WH2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
#List of the regions
list(set(list(WH2016['Region'])))
# Out:
# ['Middle East and Northern Africa',
#  'Western Europe',
#  'North America',
#  'Eastern Asia',
#  'Sub-Saharan Africa',
#  'Latin America and Caribbean',
#  'Southeastern Asia',
#  'Central and Eastern Europe',
#  'Australia and New Zealand',
#  'Southern Asia']

# %% [markdown]
# #### For 2016 Dataframe, there are 10 regions

# %%
#List of regions for 2015 Dataframe
list(set(list(WH2015['Region'])))
# Out:
# ['Middle East and Northern Africa',
#  'Western Europe',
#  'North America',
#  'Eastern Asia',
#  'Sub-Saharan Africa',
#  'Latin America and Caribbean',
#  'Southeastern Asia',
#  'Central and Eastern Europe',
#  'Australia and New Zealand',
#  'Southern Asia']

# %%
#Checking values per region
WH2015['Region'].value_counts(dropna=False)
# Out:
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %%
WH2016['Region'].value_counts(dropna=False)
# Out:
# Region
# Sub-Saharan Africa                 38
# Central and Eastern Europe         29
# Latin America and Caribbean        24
# Western Europe                     21
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64

# %% [markdown]
# #### Both dataframe has 10 regions

# %%
#dropping 'Lower Confidence Interval' and 'Upper Confidence Interval' and 'Region'
WH2016 = WH2016.drop('Lower Confidence Interval', axis=1)
WH2016 = WH2016.drop('Upper Confidence Interval', axis=1)
WH2016 = WH2016.drop('Region', axis=1)

# %% [markdown]
# ### Cleaning 2017 Data

# %%
WH2017 = pd.read_csv(r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness/World Happines CSVs/2017.csv', index_col = False)

# %%
WH2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %% [markdown]
# #### Need to rename columns and drop columns

# %%
WH2017.rename(columns = {'Happiness.Rank' : 'Happiness Rank', 'Happiness.Score':'Happiness Score', 'Economy..GDP.per.Capita.':'Economy (GDP per Capita)', 'Health..Life.Expectancy.':'Health (Life Expectancy)', 'Trust..Government.Corruption.':'Trust (Government Corruption)', 'Dystopia.Residual':'Dystopia Residual'}, inplace = True)

# %%
WH2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness Rank                 155 non-null    int64
#  2   Happiness Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy (GDP per Capita)       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health (Life Expectancy)       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust (Government Corruption)  155 non-null    float64
#  11  Dystopia Residual              155 non-null    float64
# ...

# %%
#dropping whisker
WH2017 = WH2017.drop('Whisker.high', axis=1)

# %%
WH2017 = WH2017.drop('Whisker.low', axis=1)

# %%
WH2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness Rank                 155 non-null    int64
#  2   Happiness Score                155 non-null    float64
#  3   Economy (GDP per Capita)       155 non-null    float64
#  4   Family                         155 non-null    float64
#  5   Health (Life Expectancy)       155 non-null    float64
#  6   Freedom                        155 non-null    float64
#  7   Generosity                     155 non-null    float64
#  8   Trust (Government Corruption)  155 non-null    float64
#  9   Dystopia Residual              155 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 12.2+ KB

# %%
WH2017.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      155.000000       155.000000                155.000000  155.000000
# mean        78.000000         5.354019                  0.984718    1.188898
# std         44.888751         1.131230                  0.420793    0.287263
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         39.500000         4.505500                  0.663371    1.042635
# 50%         78.000000         5.279000                  1.064578    1.253918
# 75%        116.500000         6.101500                  1.318027    1.414316
# max        155.000000         7.537000                  1.870766    1.610574
#
#        Health (Life Expectancy)     Freedom  Generosity  \
# count                155.000000  155.000000  155.000000
# mean                   0.551341    0.408786    0.246883
# std                    0.237073    0.149997    0.134780
# ...

# %%
#Finding Missing Values
WH2017.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Dystopia Residual                0
# dtype: int64

# %%
#Finding Duplicates
WH2017_dups = WH2017[WH2017.duplicated()]

# %%
WH2017_dups
# Out:
# Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption), Dystopia Residual]
# Index: []

# %%
#Adding a Year Column
WH2017['Year'] = '2017'

# %%
WH2017.head(1)
# Out:
#   Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Norway               1            7.537                  1.616463
#
#      Family  Health (Life Expectancy)   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
#
#    Trust (Government Corruption)  Dystopia Residual  Year
# 0                       0.315964           2.277027  2017

# %%
WH2018 = pd.read_csv(r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness/World Happines CSVs/2018.csv', index_col = False)

# %%
WH2018.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# ### Just noticed that 2017 and 2018 do not have a Region column. Region category will based it off on 2015 categorizing

# %% [markdown]
# #### 1. Adding 'Region' to 2017 dataframe

# %%
# Adding 'Australia and New Zealand'
WH2017.loc[(WH2017['Country'] == 'Australia') & (WH2017['Country'] =='New Zealand'),'Region'] ='Australia and New Zealand'

# %%
WH2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health (Life Expectancy)   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust (Government Corruption)  Dystopia Residual  Year Region
# 0                       0.315964           2.277027  2017    nan
# ...

# %%
#now that it works, add the other region, then check for nan
WH2017.loc[(WH2017['Country'] == 'Czech Republic'),'Region'] ='Central and Eastern Europe'

# %%
WH2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0       Norway               1            7.537                  1.616463
# 1      Denmark               2            7.522                  1.482383
# 2      Iceland               3            7.504                  1.480633
# 3  Switzerland               4            7.494                  1.564980
# 4      Finland               5            7.469                  1.443572
#
#      Family  Health (Life Expectancy)   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
# 1  1.551122                  0.792566  0.626007    0.355280
# 2  1.610574                  0.833552  0.627163    0.475540
# 3  1.516912                  0.858131  0.620071    0.290549
# 4  1.540247                  0.809158  0.617951    0.245483
#
#    Trust (Government Corruption)  Dystopia Residual  Year Region
# 0                       0.315964           2.277027  2017    nan
# ...

# %%
#dropping 'Region' for now
WH2017 = WH2017.drop('Region', axis=1)

# %%
WH2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness Rank                 155 non-null    int64
#  2   Happiness Score                155 non-null    float64
#  3   Economy (GDP per Capita)       155 non-null    float64
#  4   Family                         155 non-null    float64
#  5   Health (Life Expectancy)       155 non-null    float64
#  6   Freedom                        155 non-null    float64
#  7   Generosity                     155 non-null    float64
#  8   Trust (Government Corruption)  155 non-null    float64
#  9   Dystopia Residual              155 non-null    float64
#  10  Year                           155 non-null    object
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.4+ KB

# %% [markdown]
# ### ** So I will add 'Year' to each dataframe, then combine all of them. From there that's when I'll add region per country. **

# %%
WH2018 = pd.read_csv(r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness/World Happines CSVs/2018.csv', index_col = False)

# %% [markdown]
# #### Cleaning 2018 Data

# %%
WH2018.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      156.000000       156.000000                156.000000  156.000000
# mean        78.500000         5.375917                  0.891449    1.213237
# std         45.177428         1.119506                  0.391921    0.302372
# min          1.000000         2.905000                  0.000000    0.000000
# 25%         39.750000         4.453750                  0.616250    1.066750
# 50%         78.500000         5.378000                  0.949500    1.255000
# 75%        117.250000         6.168500                  1.197750    1.463000
# max        156.000000         7.632000                  2.096000    1.644000
#
#        Health (Life Expectancy)     Freedom  Generosity  \
# count                156.000000  156.000000  156.000000
# mean                   0.597346    0.454506    0.181006
# std                    0.247579    0.162424    0.098471
# ...

# %%
WH2018.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    1
# dtype: int64

# %%
#nulls will be left on for now. There might be more nulls once I merge the cells together

# %%
#Finding Duplicates
WH2018_dups = WH2018[WH2018.duplicated()]

# %%
WH2018_dups
# Out:
# Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Generosity, Trust (Government Corruption)]
# Index: []

# %%
#no duplicates

# %%
#Adding a Year Column
WH2018['Year'] = '2018'

# %%
WH2018.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland               1            7.632                     1.305
# 1       Norway               2            7.594                     1.456
# 2      Denmark               3            7.555                     1.351
# 3      Iceland               4            7.495                     1.343
# 4  Switzerland               5            7.487                     1.420
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.592                     0.874    0.681       0.202
# 1   1.582                     0.861    0.686       0.286
# 2   1.590                     0.868    0.683       0.284
# 3   1.644                     0.914    0.677       0.353
# 4   1.549                     0.927    0.660       0.256
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2018
# 1                          0.340  2018
# 2                          0.408  2018
# ...

# %% [markdown]
# ### Cleaning 2019 dataframe

# %%
WH2019 = pd.read_csv(r'/Users/jonahsnewmacbook/Desktop/Data Analytics/Data Immersion/Achievement 6/World Happiness/World Happines CSVs/2019.csv', index_col = False)

# %%
WH2019.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Finland               1            7.769                     1.340
# 1      Denmark               2            7.600                     1.383
# 2       Norway               3            7.554                     1.488
# 3      Iceland               4            7.494                     1.380
# 4  Netherlands               5            7.488                     1.396
#
#    Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0   1.587                     0.986    0.596                          0.393
# 1   1.573                     0.996    0.592                          0.410
# 2   1.582                     1.028    0.603                          0.341
# 3   1.624                     1.026    0.591                          0.118
# 4   1.522                     0.999    0.557                          0.298
#
#    Generosity
# 0       0.153
# 1       0.252
# 2       0.271
# ...

# %%
#Finding Missing Values
WH2019.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# dtype: int64

# %%
#Finding Duplicates
WH2019_dups = WH2019[WH2019.duplicated()]

# %%
WH2019_dups
# Out:
# Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
#no duplicates

# %%
#Adding a Year Column
WH2019['Year'] = '2019'

# %%
WH2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        156 non-null    object
#  1   Happiness Rank                 156 non-null    int64
#  2   Happiness Score                156 non-null    float64
#  3   Economy (GDP per Capita)       156 non-null    float64
#  4   Family                         156 non-null    float64
#  5   Health (Life Expectancy)       156 non-null    float64
#  6   Freedom                        156 non-null    float64
#  7   Trust (Government Corruption)  156 non-null    float64
#  8   Generosity                     156 non-null    float64
#  9   Year                           156 non-null    object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 12.3+ KB

# %% [markdown]
# ### I do have happiness data score for the years 2021 to 2023 however it is not showing the 6 factor scores. I will use the data later

# %%
WH2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Happiness Rank                 158 non-null    int64
#  2   Happiness Score                158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 12.5+ KB

# %%
#Lets try concat()
WH1516 = [WH2015, WH2016]

# %%
WH1516concat = pd.concat(WH1516)

# %%
WH1516concat
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 152        Benin             153            3.484                   0.39499
# 153  Afghanistan             154            3.360                   0.38227
# 154         Togo             155            3.303                   0.28123
# 155        Syria             156            3.069                   0.74719
# 156      Burundi             157            2.905                   0.06831
#
#       Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
WH171819 = [WH2017, WH2018, WH2019]

# %%
WH171819concat = pd.concat(WH171819)

# %%
WH171819concat
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %%
WH_15to19concat = [WH1516concat, WH171819concat]

# %%
WH_15to19 = pd.concat(WH_15to19concat)

# %%
WH_15to19
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 151                    Rwanda             152            3.334
# 152                  Tanzania             153            3.231
# 153               Afghanistan             154            3.203
# 154  Central African Republic             155            3.083
# 155               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# ### Create a Region Flag

# %%
#Creating 'Australia and New Zealand'
WH_15to19.loc[(WH_15to19['Country'] == 'Australia'), 'Region'] ='Australia and New Zealand'
WH_15to19.loc[(WH_15to19['Country'] == 'New Zealand'), 'Region'] = 'Australia and New Zealand'

# %%
WH_15to19.head(1)
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual  Year          Region
# 0     0.29678            2.51738  2015  Western Europe

# %%
#Creating 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Albania'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Armenia'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Azerbaijan'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Belarus'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Bosnia and Herzegovina'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Bulgaria'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Croatia'), 'Region'] = 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Czech Republic'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Estonia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Georgia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Hungary'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Kazakhstan'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Kosovo'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Kyrgyzstan'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Latvia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Lithuania'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Macedonia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Moldova'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Montenegro'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'North Macedonia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Poland'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Romania'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Russia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Serbia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Slovakia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Slovenia'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Tajikistan'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Turkmenistan'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Ukraine'), 'Region']= 'Central and Eastern Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Uzbekistan'), 'Region'] = 'Central and Eastern Europe'

# %%
#Creating 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'China'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Hong Kong'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Hong Kong S.A.R., China'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Japan'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Mongolia'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'South Korea'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Taiwan Province of China'), 'Region'] = 'Eastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Taiwan'), 'Region'] = 'Eastern Asia'

# %%
#Creating 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Argentina'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Belize'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Bolivia'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Brazil'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Chile'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Colombia'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Costa Rica'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Dominican Republic'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Ecuador'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'El Salvador'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Guatemala'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Haiti'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Honduras'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Jamaica'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Mexico'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Nicaragua'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Panama'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Paraguay'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Peru'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Puerto Rico'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Suriname'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Trinidad and Tobago'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Trinidad & Tobago'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Uruguay'), 'Region'] = 'Latin America and Caribbean'
WH_15to19.loc[(WH_15to19['Country'] == 'Venezuela'), 'Region'] = 'Latin America and Caribbean'

# %%
# Creating 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Algeria'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Bahrain'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Egypt'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Iran'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Iraq'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Israel'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Jordan'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Kuwait'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Lebanon'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Libya'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Morocco'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Oman'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Palestinian Territories'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Qatar'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Saudi Arabia'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Syria'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Tunisia'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Turkey'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'United Arab Emirates'), 'Region'] = 'Middle East and Northern Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Yemen'), 'Region'] = 'Middle East and Northern Africa'

# %%
#Creating 'North America'
WH_15to19.loc[(WH_15to19['Country'] == 'Canada'), 'Region'] = 'North America'
WH_15to19.loc[(WH_15to19['Country'] == 'United States'), 'Region'] = 'North America'

# %%
# Creating 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Cambodia'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Indonesia'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Laos'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Malaysia'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Myanmar'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Philippines'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Singapore'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Thailand'), 'Region'] = 'Southeastern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Vietnam'), 'Region'] = 'Southeastern Asia'

# %%
# Creating 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Afghanistan'), 'Region'] = 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Bangladesh'), 'Region'] = 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Bhutan'), 'Region'] = 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'India'), 'Region'] = 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Nepal'), 'Region'] = 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Pakistan'), 'Region'] = 'Southern Asia'
WH_15to19.loc[(WH_15to19['Country'] == 'Sri Lanka'), 'Region'] = 'Southern Asia'

# %%
#Creating 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Angola'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Benin'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Botswana'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Burkina Faso'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Burundi'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Cameroon'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Central African Republic'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Chad'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Comoros'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Congo (Brazzaville)'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Congo (Kinshasa)'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Djibouti'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Ethiopia'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Gabon'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Gambia'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Ghana'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Guinea'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Ivory Coast'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Kenya'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Lesotho'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Liberia'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Madagascar'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Malawi'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Mali'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Mauritania'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Mauritius'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Mozambique'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Namibia'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Nigeria'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Niger'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Rwanda'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Senegal'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Sierra Leone'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Somalia'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Somaliland region'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Somaliland Region'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'South Africa'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'South Sudan'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Sudan'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Swaziland'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Tanzania'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Togo'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Uganda'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Zambia'), 'Region'] = 'Sub-Saharan Africa'
WH_15to19.loc[(WH_15to19['Country'] == 'Zimbabwe'), 'Region'] = 'Sub-Saharan Africa'

# %%
# Creating 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Austria'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Belgium'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Cyprus'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Denmark'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Finland'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'France'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Germany'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Greece'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Iceland'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Ireland'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Italy'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Luxembourg'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Malta'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Netherlands'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'North Cyprus'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Northern Cyprus'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Norway'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Portugal'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Spain'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Sweden'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'Switzerland'), 'Region'] = 'Western Europe'
WH_15to19.loc[(WH_15to19['Country'] == 'United Kingdom'), 'Region'] = 'Western Europe'

# %%
#finding missing values in WH_15to19
WH_15to19.isnull().sum()
# Out:
# Country                            0
# Happiness Rank                     0
# Happiness Score                    0
# Economy (GDP per Capita)           0
# Family                             0
# Health (Life Expectancy)           0
# Freedom                            0
# Trust (Government Corruption)      1
# Generosity                         0
# Dystopia Residual                312
# Year                               0
# Region                             0
# dtype: int64

# %%
WH_15to19.head(10)
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
# 5      Finland               6            7.406                   1.29025
# 6  Netherlands               7            7.378                   1.32944
# 7       Sweden               8            7.364                   1.33171
# 8  New Zealand               9            7.286                   1.25018
# 9    Australia              10            7.284                   1.33358
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
WH_15to19['Region'].value_counts(dropna=False)
# Out:
# Region
# Sub-Saharan Africa                 196
# Central and Eastern Europe         145
# Latin America and Caribbean        111
# Western Europe                     105
# Middle East and Northern Africa     96
# Southeastern Asia                   44
# Southern Asia                       35
# Eastern Asia                        30
# North America                       10
# Australia and New Zealand           10
# Name: count, dtype: int64

# %%
#exporting this new dataframe
WH_15to19.to_csv(os.path.join(path,'WH_15to19.csv'))
